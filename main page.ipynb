# %%
from Admin import *
from Student import *
from Faculty import *
from function import *
import sys
def Menu():
    while True:
        print("Main Menu")
        print()
        print("*"*50)
        print("1.>  Admin Menu")
        print("2.>  Student Menu")
        print("3.>  Faculty Menu")
        print("0.>  Exit\n")
        print("*" * 50)
        n = int(input("Enter Your Choice: "))
        if n==1:
            Admin_Menu()
        elif n==2:
            Student_Menu()
        elif n==3:
            Faculty_Menu()   
        elif n==0:
            sys.exit(0)
        else:
            print("Invalid Option")
Menu()
# Out:
# Main Menu
#
# **************************************************
# 1.>  Admin Menu
# 2.>  Student Menu
# 3.>  Faculty Menu
# 0.>  Exit
#
# **************************************************
# Enter Your Choice: 1
# **************************************************
# 1.>  Insert Book
# 2.>  Display Book List
# 3.>  Book Search
# 4.>  Book Issue for Student
# 5.>  Book Issue for Faculty
# 6.>  Book Return of Student
# 4.>  Book Return of Faculty
# 8.>  Delete Book Record
# 9.>  Insert New Student
# 10.> Display Student List
# 11.> Student Search
# 12.> Delete Student Record
# 13.> Insert New Faculty
# 14.> Display Faculty
# 15.> Faculty Search
# 16.> Delete Faculty
# 0> Exit
#
# **************************************************
# Enter Your Choice: 1
# Enter New Book's Detail:
# Enter Number of Books to be Entered: 1
# Enter Book Title: ds
# Enter Author Name of ds Book: karamuchi
# Enter Publication of ds Book: nk publication
# Enter Publication Year of ds Book: 2011
# ...
